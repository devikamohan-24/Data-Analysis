# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Companies-House-search-results.csv')
data.head()
# Out:
#                                         company_name company_number  \
# 0  ANIMAL MEDICINES TRAINING REGULATORY AUTHORITY...       02140832
# 1              GBM AUTHORISED REPRESENTATIVE LIMITED       03916444
# 2                 WESTGATE SAFETY & TRAINING LIMITED       05207326
# 3                                    BIRMINGHAM LGBT       07203554
# 4                        TRURO PHYSIOTHERAPY LIMITED       09194419
#
#   company_status                                       company_type  \
# 0         Active  Private limited by guarantee without share cap...
# 1         Active                            Private limited company
# 2         Active                            Private limited company
# 3         Active  Private Limited Company by guarantee without s...
# 4         Active                            Private limited company
#
#   company_subtype  dissolution_date incorporation_date  removed_date  \
# 0             NaN               NaN         1987-06-18           NaN
# ...

# %%
data.shape
# Out:
# (5000, 11)

# %%
x = data.loc[data['registered_office_address'] == 'KT3']

# %%
print (x)
# Out:
# Empty DataFrame
# Columns: [company_name, company_number, company_status, company_type, company_subtype, dissolution_date, incorporation_date, removed_date, registered_date, nature_of_business, registered_office_address]
# Index: []

# %%
y.shape
# Out:
# (32,)

# %%
z = x.iloc[0:1350,6:7].value_counts()
print(z)
# Out:
# LOCALAUTHORITY
# London Borough of Croydon Council                   127
# London Borough of Barnet Council                     83
# London Borough of Redbridge Council                  82
# London Borough of Enfield Council                    81
# London Borough of Sutton Council                     78
# London Borough of Brent Council                      58
# London Borough of Havering Council                   57
# London Borough of Lewisham Council                   56
# London Borough of Harrow Council                     55
# London Borough of Bromley Council                    53
# London Borough of Waltham Forest Council             49
# London Borough of Hillingdon Council                 47
# London Borough of Ealing Council                     46
# London Borough of Richmond upon Thames Council       44
# London Borough of Lambeth Council                    44
# London Borough of Greenwich Council                  43
# ...

# %%
z.shape
# Out:
# (32,)

# %%
w = data.loc[data['DISTRICT'] == 'Hammersmith & Fulham Borough']
print(w)
# Out:
#        Ref_ID  Company ID  COUNTRY  REGION  COUNTY  \
# 1822     4990         NaN  England  London  London
# 6048    15858         NaN  England  London  London
# 8607    27084         NaN  England  London  London
# 10695   35510         NaN  England  London  London
# 11250   40118         NaN  England  London  London
# 11251   40119         NaN  England  London  London
# 12403   47597         NaN  England  London  London
# 12721   51696         NaN  England  London  London
# 12992   52831         NaN  England  London  London
#
#                            DISTRICT  \
# 1822   Hammersmith & Fulham Borough
# 6048   Hammersmith & Fulham Borough
# 8607   Hammersmith & Fulham Borough
# 10695  Hammersmith & Fulham Borough
# 11250  Hammersmith & Fulham Borough
# 11251  Hammersmith & Fulham Borough
# 12403  Hammersmith & Fulham Borough
# 12721  Hammersmith & Fulham Borough
# 12992  Hammersmith & Fulham Borough
#
#                                          LOCALAUTHORITY  \
# ...

# %%
data.drop(['Company ID'], axis=1)
# Out:
#             Ref_ID  COUNTRY                  REGION              COUNTY  \
# 0                2  England  Yorkshire & The Humber     South Yorkshire
# 1                7  England  Yorkshire & The Humber     South Yorkshire
# 2                9  England  Yorkshire & The Humber     South Yorkshire
# 3               10  England  Yorkshire & The Humber     South Yorkshire
# 4               14  England  Yorkshire & The Humber     South Yorkshire
# ...            ...      ...                     ...                 ...
# 17893  65432244740  England  Yorkshire & The Humber  North Lincolnshire
# 17894  65432244744  England      South West England            Cornwall
# 17895  65432244835  England  Yorkshire & The Humber      West Yorkshire
# 17896  65432244910  England      South East England              Surrey
# 17897  65432244941  England         East of England             Suffolk
#
#                       DISTRICT  \
# 0               Sheffield Area
# 1               Sheffield Area
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8644/4106548628.py in <module>
# ----> 1 d = data.groupby('Region')
#       2 print(d)
#
# NameError: name 'data' is not defined
